# %% [markdown]
# <a href="https://colab.research.google.com/github/danielbr20998/Atividades-Senai/blob/main/Pandinha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
# Incompleto

# %%
s1 = pd.Series([1,2,-5,0])

# %%
s1
# Out:
# 0    1
# 1    2
# 2   -5
# 3    0
# dtype: int64

# %%
s1.values
# Out:
# array([ 1,  2, -5,  0])

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s2= pd.Series([1,2,-5,0], index=['a','b','c','d'])

# %%
s2
# Out:
# a    1
# b    2
# c   -5
# d    0
# dtype: int64

# %%
s2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
s2['a']=1000

# %%
s2
# Out:
# a    1000
# b       2
# c      -5
# d       0
# dtype: int64

# %%
s2[s2>0]
# Out:
# a    1000
# b       2
# dtype: int64

# %%
s2*2
# Out:
# a    2000
# b       4
# c     -10
# d       0
# dtype: int64

# %%
s2.isnull()
# Out:
# a    False
# b    False
# c    False
# d    False
# dtype: bool

# %%
dados = {
    'estado': ['SP','MG','PR','SP','MG','PR'],
    'ano': [2023, 2025, 2025, 2024, 2023, 2024],
    'população': [45.9, 21.3, 16.9, 46.6, 24.2, 17.3]
}

# %%
df1=pd.DataFrame(dados)

# %%
df1
# Out:
#   estado   ano  população
# 0     SP  2023       45.9
# 1     MG  2025       21.3
# 2     PR  2025       16.9
# 3     SP  2024       46.6
# 4     MG  2023       24.2
# 5     PR  2024       17.3

# %%
df1.head(2)
# Out:
#   estado   ano  população
# 0     SP  2023       45.9
# 1     MG  2025       21.3

# %%
df1.tail(2)
# Out:
#   estado   ano  população
# 4     MG  2023       24.2
# 5     PR  2024       17.3

# %%
df1.sample(2)
# Out:
#   estado   ano  população
# 3     SP  2024       46.6
# 5     PR  2024       17.3

# %%
df2=pd.DataFrame(dados, columns=['ano','estado','população'])

# %%
df2
# Out:
#     ano estado  população
# 0  2023     SP       45.9
# 1  2025     MG       21.3
# 2  2025     PR       16.9
# 3  2024     SP       46.6
# 4  2023     MG       24.2
# 5  2024     PR       17.3

# %%
df2.dtypes
# Out:
# ano            int64
# estado        object
# população    float64
# dtype: object

# %%
df2.iloc[1:3,[1,2]]
# Out:
#   estado  população
# 1     MG       21.3
# 2     PR       16.9

# %%
df2
# Out:
#     ano estado  população
# 0  2023     SP       45.9
# 1  2025     MG       21.3
# 2  2025     PR       16.9
# 3  2024     SP       46.6
# 4  2023     MG       24.2
# 5  2024     PR       17.3
